# %% [markdown]
# # chimera26: shared LFSR / IID and EPIX
# Run all cells on PYNQ-Z1 using its hardware-enabled Python kernel. Set `trials` below to 1–1000. Only one notebook may control the FPGA at a time.

# %%
# Keep this notebook in its demo folder so the runner finds the matching files.
from pathlib import Path
import json, subprocess, sys, uuid
project = Path.cwd()
assert (project / "run.py").is_file()
trials = 1  # Increase to 1000 for a full campaign.
output = project / "runs" / uuid.uuid4().hex

# %%
# Use this kernel's Python to load the FPGA and run the selected policy.
subprocess.check_call([sys.executable, str(project / "run.py"), "--mode", "paired", "--trials", str(trials), "--output", str(output)])
# Out:
# 0

# %%
# successes counts trials that reached the optimum; mean_rng_words counts fresh draws.
summary = json.loads((output / "SUMMARY.json").read_text())
print(json.dumps(summary, indent=2))
print("Saved every trial to", output.relative_to(project))
# Out:
# {
#   "IID": {
#     "trials": 1,
#     "successes": 1,
#     "mean_rng_words": 26650.0,
#     "mean_rng_steps": 852800.0,
#     "mean_core_seconds": 0.023983980000000002,
#     "mean_host_seconds": 0.024960775000010926,
#     "mean_reuse": -0.0,
#     "mean_updates": 26624.0,
#     "total_core_seconds": 0.023983980000000002,
#     "total_host_seconds": 0.024960775000010926
#   },
#   "EPIX": {
#     "trials": 1,
#     "successes": 1,
#     "mean_rng_words": 16482.0,
#     "mean_rng_steps": 527424.0,
#     "mean_core_seconds": 0.02062854,
#     "mean_host_seconds": 0.021631114000001617,
#     "mean_reuse": 10168.0,
#     "mean_updates": 26624.0,
#     "total_core_seconds": 0.02062854,
#     "total_host_seconds": 0.021631114000001617
#   }
# }
# Saved every trial to runs/73b6f1f218dc49ba9a2831133f35b411

# %% [markdown]
# Each trial completes 1024 sweeps. IID requests a new word for every update. EPIX reuses a cached word only when its supported state, quantized field, and age checks permit.
# Mean core time is per trial; total core time sums all trials.
